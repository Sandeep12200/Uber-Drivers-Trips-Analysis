# %% [markdown]
# #### Instructions:
#
# For all questions after 10th, Please only use the data specified in the note given just below the question
# You need to add answers in the same file i.e. PDS_UberDriveProject_Questions.ipynb'

# %% [markdown]
# # Load the necessary libraries. Import and load the dataset with a name uber_drives .

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Get the Data
ud =pd.read_csv('/content/uberdrive.csv')
ud
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %% [markdown]
# ### Q1. Show the last 10 records of the dataset. (2 points)

# %%
ud.tail(10)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1145  12/30/2016 10:15  12/30/2016 10:33  Business           Karachi
# 1146  12/30/2016 11:31  12/30/2016 11:56  Business           Karachi
# 1147  12/30/2016 15:41  12/30/2016 16:03  Business           Karachi
# 1148  12/30/2016 16:45  12/30/2016 17:08  Business           Karachi
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business           Karachi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 1145           Karachi     2.8  Errand/Supplies
# 1146           Karachi     2.9  Errand/Supplies
# 1147           Karachi     4.6  Errand/Supplies
# ...

# %% [markdown]
# ## Q2. Show the first 10 records of the dataset. (2 points)

# %%
ud.head(10)
# Out:
#         START_DATE*         END_DATE* CATEGORY*           START*  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business      Fort Pierce
# 5  01-06-2016 17:15  01-06-2016 17:19  Business  West Palm Beach
# 6  01-06-2016 17:30  01-06-2016 17:35  Business  West Palm Beach
# 7  01-07-2016 13:27  01-07-2016 13:33  Business             Cary
# 8  01-10-2016 08:05  01-10-2016 08:25  Business             Cary
# 9  01-10-2016 12:17  01-10-2016 12:44  Business          Jamaica
#
#              STOP*  MILES*         PURPOSE*
# 0      Fort Pierce     5.1   Meal/Entertain
# 1      Fort Pierce     5.0              NaN
# 2      Fort Pierce     4.8  Errand/Supplies
# 3      Fort Pierce     4.7          Meeting
# ...

# %% [markdown]
# ## Q3. Show the dimension(number of rows and columns) of the dataset. (2 points)

# %%
dimension= ud.shape
print("Dimension of the dataset:",dimension)
# Out:
# Dimension of the dataset: (1155, 7)

# %% [markdown]
# ## Q4. Show the size (Total number of elements) of the dataset. (2 points)

# %%
Size= ud.size
print("Total Number of elements in the dataset:",Size)
# Out:
# Total Number of elements in the dataset: 8085

# %% [markdown]
# ## Q5. Display the information about all the variables of the data set. What can you infer from the output?(2 +2 points)
#
# #### Hint: Information includes - Total number of columns,variable data-types, number of non-null values in a variable, and usage

# %%
inf= ud.info()
inf
print("""The dataset is mostly complete, except for the PURPOSE* column, which has 502 missing values.
The majority of the columns are object type, except for MILES* which is numerical.""")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1155 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1155 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB
# The dataset is mostly complete, except for the PURPOSE* column, which has 502 missing values.
# The majority of the columns are object type, except for MILES* which is numerical.

# %% [markdown]
# ### Q6. Check for missing values. (3 points)
#
# ####  Note: Output should contain only one boolean value

# %%
ud.isnull()
# Out:
#       START_DATE*  END_DATE*  CATEGORY*  START*  STOP*  MILES*  PURPOSE*
# 0           False      False      False   False  False   False     False
# 1           False      False      False   False  False   False      True
# 2           False      False      False   False  False   False     False
# 3           False      False      False   False  False   False     False
# 4           False      False      False   False  False   False     False
# ...           ...        ...        ...     ...    ...     ...       ...
# 1150        False      False      False   False  False   False     False
# 1151        False      False      False   False  False   False     False
# 1152        False      False      False   False  False   False     False
# 1153        False      False      False   False  False   False     False
# 1154        False      False      False   False  False   False     False
#
# [1155 rows x 7 columns]

# %% [markdown]
# ## Q7. How many missing values are present in the entire dataset? (2 points)

# %%
missing_values=ud.isna().sum().sum()
print(missing_values,"values are missing in the dataset.")
# Out:
# 502 values are missing in the dataset.

# %% [markdown]
# ## Q8. Get the summary of the original data. (2 points).
#
# #### Hint: Summary includes- Count,Mean, Std, Min, 25%,50%,75% and max

# %%
ud.describe()
# Out:
#             MILES*
# count  1155.000000
# mean     10.566840
# std      21.579106
# min       0.500000
# 25%       2.900000
# 50%       6.000000
# 75%      10.400000
# max     310.300000

# %% [markdown]
# ## Q9. Drop the missing values and store the data in a new dataframe (name it"df") (2-points)
#
# #### Note: Dataframe "df" will not contain any missing value

# %%
df =ud.dropna()
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# 5     01-06-2016 17:15  01-06-2016 17:19  Business   West Palm Beach
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %% [markdown]
# ## Q10. Check the information of the dataframe(df). (2 points)
#
# #### Hint: Information includes - Total number of columns,variable data-types, number of non-null values in a variable, and usage

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 653 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  653 non-null    object
#  1   END_DATE*    653 non-null    object
#  2   CATEGORY*    653 non-null    object
#  3   START*       653 non-null    object
#  4   STOP*        653 non-null    object
#  5   MILES*       653 non-null    float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 40.8+ KB

# %% [markdown]
# ## Q11. Get the unique start locations. (2 points)
# #### Note: This question is based on the dataframe with no 'NA' values

# %%
u_start= df['START*'].unique()
print("These are the Start locations :",u_start)
# Out:
# These are the Start locations : ['Fort Pierce' 'West Palm Beach' 'Cary' 'Jamaica' 'New York' 'Elmhurst'
#  'Midtown' 'East Harlem' 'Flatiron District' 'Midtown East'
#  'Hudson Square' 'Lower Manhattan' "Hell's Kitchen" 'Downtown' 'Gulfton'
#  'Houston' 'Eagan Park' 'Morrisville' 'Durham' 'Farmington Woods'
#  'Lake Wellingborough' 'Fayetteville Street' 'Raleigh' 'Whitebridge'
#  'Hazelwood' 'Fairmont' 'Meredith Townes' 'Apex' 'Chapel Hill'
#  'Northwoods' 'Edgehill Farms' 'Eastgate' 'East Elmhurst'
#  'Long Island City' 'Katunayaka' 'Colombo' 'Nugegoda' 'Unknown Location'
#  'Islamabad' 'R?walpindi' 'Noorpur Shahan' 'Preston' 'Heritage Pines'
#  'Tanglewood' 'Waverly Place' 'Wayne Ridge' 'Westpark Place' 'East Austin'
#  'The Drag' 'South Congress' 'Georgian Acres' 'North Austin'
#  'West University' 'Austin' 'Katy' 'Sharpstown' 'Sugar Land' 'Galveston'
#  'Port Bolivar' 'Washington Avenue' 'Briar Meadow' 'Latta' 'Jacksonville'
# ...

# %% [markdown]
# ## Q12. What is the total number of unique start locations? (3 points)
# #### Note: Use the original dataframe without dropping 'NA' values

# %%
n_start= ud['START*'].nunique()
print("Total number of unique Start locations :",n_start)
# Out:
# Total number of unique Start locations : 176

# %% [markdown]
# ## Q13. What is the total number of unique stop locations. (3 points)
# #### Note: Use the original dataframe without dropping 'NA' values.

# %%
u_stop= ud['STOP*'].unique()
print("These are the Stop locations :",u_stop)
# Out:
# These are the Stop locations : ['Fort Pierce' 'West Palm Beach' 'Palm Beach' 'Cary' 'Morrisville'
#  'New York' 'Queens' 'East Harlem' 'NoMad' 'Midtown' 'Midtown East'
#  'Hudson Square' 'Lower Manhattan' "Hell's Kitchen" 'Queens County'
#  'Gulfton' 'Downtown' 'Houston' 'Jamestown Court' 'Durham' 'Whitebridge'
#  'Lake Wellingborough' 'Raleigh' 'Umstead' 'Hazelwood' 'Westpark Place'
#  'Meredith Townes' 'Leesville Hollow' 'Apex' 'Chapel Hill'
#  'Williamsburg Manor' 'Macgregor Downs' 'Edgehill Farms' 'Northwoods'
#  'Tanglewood' 'Preston' 'Walnut Terrace' 'Jackson Heights' 'East Elmhurst'
#  'Midtown West' 'Long Island City' 'Jamaica' 'Unknown Location' 'Colombo'
#  'Nugegoda' 'Katunayaka' 'Islamabad' 'R?walpindi' 'Noorpur Shahan'
#  'Heritage Pines' 'Waverly Place' 'Wayne Ridge' 'Depot Historic District'
#  'Weston' 'West University' 'South Congress' 'Arts District'
#  'Congress Ave District' 'Red River District' 'The Drag'
# ...

# %% [markdown]
# ## Q14. Display all Uber trips that has the starting point as San Francisco. (3 points)
# #### Note: Use the original dataframe without dropping the 'NA' values.

# %%
sf = ud[ud["START*"] == "San Francisco"]
sf
# Out:
#           START_DATE*         END_DATE* CATEGORY*         START*       STOP*  \
# 362  05-09-2016 14:39  05-09-2016 15:06  Business  San Francisco   Palo Alto
# 440   6/14/2016 16:09   6/14/2016 16:39  Business  San Francisco  Emeryville
# 836  10/19/2016 14:02  10/19/2016 14:31  Business  San Francisco    Berkeley
# 917  11-07-2016 19:17  11-07-2016 19:57  Business  San Francisco    Berkeley
# 919  11-08-2016 12:16  11-08-2016 12:49  Business  San Francisco    Berkeley
# 927  11-09-2016 18:40  11-09-2016 19:17  Business  San Francisco     Oakland
# 933  11-10-2016 15:17  11-10-2016 15:22  Business  San Francisco     Oakland
# 966  11/15/2016 20:44  11/15/2016 21:00  Business  San Francisco    Berkeley
#
#      MILES*         PURPOSE*
# 362    20.5  Between Offices
# 440    11.6          Meeting
# 836    10.8              NaN
# 917    13.2  Between Offices
# 919    11.3          Meeting
# 927    12.7   Customer Visit
# 933     9.9   Temporary Site
# 966    11.8   Temporary Site

# %% [markdown]
# ## Q15. What is the most popular starting point for the Uber drivers? (3 points)
# #### Note: Use the original dataframe without dropping the 'NA' values.
#
# #### Hint:Popular means the place that is visited the most

# %%
popular_start = ud["START*"].value_counts().idxmax()
print("Most popular starting point is", popular_start,"with total of", ud['START*'].value_counts().max(),"trips.")
# Out:
# Most popular starting point is Cary with total of 201 trips.

# %% [markdown]
# ## Q16. What is the most popular dropping point for the Uber drivers? (3 points)
# #### Note: Use the original dataframe without dropping the 'NA' values.
#
# #### Hint: Popular means the place that is visited the most

# %%
popular_drop= ud['STOP*'].value_counts().idxmax()
print("Most popular Dropping point is" ,popular_drop, "with total of", ud['STOP*'].value_counts().max(),"trips.")
# Out:
# Most popular Dropping point is Cary with total of 203 trips.

# %% [markdown]
# ## Q17. What is the most frequent route taken by Uber drivers. (3 points)
# #### Note: This question is based on the new dataframe with no 'na' values.
# #### Hint-Print the most frequent route taken by Uber drivers (Route= combination of START & END points present in the Data set).

# %%
route= df['START*'] +" → "+ df['STOP*']     # combines the START & END ppoints in variable "route"

m_freq_route= route.value_counts().idxmax()
print("Most Frequent Route taken by Uber drivers is", m_freq_route, "with total of",route.value_counts().max(),"trips.")
# Out:
# Most Frequent Route taken by Uber drivers is Cary → Morrisville with total of 52 trips.

# %% [markdown]
# ## Q18. Display all types of purposes for the trip in an array. (3 points)
# #### Note: This question is based on the new dataframe with no 'NA' values.

# %%
ud.groupby('PURPOSE*')['PURPOSE*'].count()
# Out:
# PURPOSE*
# Airport/Travel       3
# Between Offices     18
# Charity ($)          1
# Commute              1
# Customer Visit     101
# Errand/Supplies    128
# Meal/Entertain     160
# Meeting            187
# Moving               4
# Temporary Site      50
# Name: PURPOSE*, dtype: int64

# %%
trip_purpose = df['PURPOSE*'].unique()
trip_purpose
# Out:
# array(['Meal/Entertain', 'Errand/Supplies', 'Meeting', 'Customer Visit',
#        'Temporary Site', 'Between Offices', 'Charity ($)', 'Commute',
#        'Moving', 'Airport/Travel'], dtype=object)

# %% [markdown]
# ## Q19. Plot a bar graph of Purpose vs Miles(Distance). What can you infer from the plot(2 +2 points)
# #### Note: Use the original dataframe without dropping the 'NA' values.
# #### Hint:You have to plot total/sum miles per purpose

# %%
total_miles_purpose = ud.groupby('PURPOSE*')['MILES*'].sum()
purpose = total_miles_purpose.index
miles = total_miles_purpose.values

colors = ['#FF6347', '#4682B4', '#32CD32', '#FFD700', '#8A2BE2', '#FF4500', '#2E8B57']

plt.bar(purpose, miles, color=colors, edgecolor='black')

plt.xlabel("Trip Purpose")
plt.ylabel("Total Miles")
plt.title("Total Miles by Trip Purpose")
plt.xticks(rotation=90)

plt.show()

# Observation : "Meeting" has the highest total miles traveled. "Customer Visit" is the second most frequent purpose.
#               "Meal/Entertain" and "Temporary Site" also contribute significantly.
#               Some purposes like "Airport/Travel" and "Moving" have very low total miles.

# %% [markdown]
# ## Q20. Display a dataframe of Purpose and the total distance travelled for that particular Purpose. (3 points)
# #### Note: Use the original dataframe without dropping "NA" values

# %%
total_miles_purpose = ud.groupby('PURPOSE*')['MILES*'].sum()

total_miles_purpose
# Out:
# PURPOSE*
# Airport/Travel       16.5
# Between Offices     197.0
# Charity ($)          15.1
# Commute             180.2
# Customer Visit     2089.5
# Errand/Supplies     508.0
# Meal/Entertain      911.7
# Meeting            2851.3
# Moving               18.2
# Temporary Site      523.7
# Name: MILES*, dtype: float64

# %% [markdown]
# ## Q21. Generate a plot showing count of trips vs category of trips. What can you infer from the plot (2 +2 points)
# #### Note: Use the original dataframe without dropping the 'NA' values.

# %%
trip_count_per_category = ud.groupby('CATEGORY*')['CATEGORY*'].count()
count= trip_count_per_category.values
category= trip_count_per_category.index

plt.pie(count, labels= category, autopct= '%1.1f%%', startangle=45, explode=[0,0.2], wedgeprops={'edgecolor': 'black'})
plt.title("Trip Category VS Count of Trips")
plt.legend(fontsize=8)

plt.show()

# Observation : Most (93.3%) of the trips belong to the Business category. This means that the users primarily uses Uber for professional use.
#               Minimal Personal Travel, Only 6.7% of the journeys are of type Personal.

# %% [markdown]
# ## Q22. What percentage of Miles were clocked under Business Category and what percentage of Miles were clocked under Personal Category ? (3 points)
#
# ### Note:Use the original dataframe without dropping the 'NA' values.

# %%
miles_category = ud.groupby('CATEGORY*')['MILES*'].sum()
total_miles = miles_category.sum()

business_miles = round((miles_category.get('Business')/total_miles)*100 , 2)
personal_miles = round((miles_category.get('Personal')/total_miles)*100 , 2)

print("Percentage of miles under Business Category:",business_miles,"%")
print("Percentage of miles under Personal Category:",personal_miles,"%")
# Out:
# Percentage of miles under Business Category: 94.12 %
# Percentage of miles under Personal Category: 5.88 %

# %% [markdown]
# ***THE END***
